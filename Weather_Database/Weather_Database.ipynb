# %%
import numpy as np
from citipy import citipy
import pandas as pd

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-90.000,high=90.000,size=2000)

# Pack each pair of latitude and longitude coordinates into a tuple
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the requests library.
import requests

# config.py file is located in the parent directory of the current folder.
# Add the parent directory to sys.path (sys.path also contains PYTHONPATH) 
import sys
# Import the API key from parent directory.
sys.path.append('../')
from config import weather_api_key

# Import the datetime module from the datetime library 
from datetime import datetime
import time

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grindavik
# Processing Record 2 of Set 1 | tonantins
# Processing Record 3 of Set 1 | nauchnyy gorodok
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | kumylzhenskaya
# Processing Record 6 of Set 1 | cahors
# Processing Record 7 of Set 1 | coihaique
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | ancud
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | bonthe
# Processing Record 13 of Set 1 | vieira de leiria
# Processing Record 14 of Set 1 | pangnirtung
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | general pico
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | krasnoselkup
# Processing Record 20 of Set 1 | goderich
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | caravelas
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | mitu
# Processing Record 25 of Set 1 | manzil tamim
# City not found. Skipping...
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | richards bay
# Processing Record 28 of Set 1 | rio gallegos
# Processing Record 29 of Set 1 | kalmunai
# Processing Record 30 of Set 1 | borlange
# City not found. Skipping...
# Processing Record 31 of Set 1 | guanare
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | ponta do sol
# Processing Record 34 of Set 1 | bafq
# Processing Record 35 of Set 1 | ardistan
# City not found. Skipping...
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | annau
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | stromness
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | suzun
# Processing Record 42 of Set 1 | victoria
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | ilulissat
# Processing Record 46 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | kruisfontein
# Processing Record 49 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 1 | nampula
# Processing Record 1 of Set 2 | qaqortoq
# Processing Record 2 of Set 2 | odweyne
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | dingle
# Processing Record 5 of Set 2 | gazanjyk
# Processing Record 6 of Set 2 | vilcun
# Processing Record 7 of Set 2 | harper
# Processing Record 8 of Set 2 | manacapuru
# Processing Record 9 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 2 | marsh harbour
# Processing Record 11 of Set 2 | imeni babushkina
# Processing Record 12 of Set 2 | sabzevar
# Processing Record 13 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 14 of Set 2 | sambava
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | west bay
# Processing Record 19 of Set 2 | burtunay
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | visby
# Processing Record 22 of Set 2 | pitsunda
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | san pedro
# Processing Record 26 of Set 2 | axim
# Processing Record 27 of Set 2 | hobyo
# Processing Record 28 of Set 2 | samarkand
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | muravlenko
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | yenisea
# City not found. Skipping...
# Processing Record 34 of Set 2 | yarada
# Processing Record 35 of Set 2 | korhogo
# Processing Record 36 of Set 2 | kabo
# Processing Record 37 of Set 2 | hambantota
# Processing Record 38 of Set 2 | darnah
# Processing Record 39 of Set 2 | resavica
# Processing Record 40 of Set 2 | cayenne
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | saint george
# Processing Record 43 of Set 2 | warangal
# Processing Record 44 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 2 | asyut
# Processing Record 46 of Set 2 | nurota
# Processing Record 47 of Set 2 | korla
# Processing Record 48 of Set 2 | chipinge
# Processing Record 49 of Set 2 | terrak
# Processing Record 50 of Set 2 | sao jose da coroa grande
# Processing Record 1 of Set 3 | guayaramerin
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | roald
# Processing Record 4 of Set 3 | husavik
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | marienburg
# Processing Record 7 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 3 | korem
# Processing Record 9 of Set 3 | chabahar
# Processing Record 10 of Set 3 | vestmanna
# Processing Record 11 of Set 3 | llanes
# Processing Record 12 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 3 | lubango
# Processing Record 14 of Set 3 | barzas
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | prainha
# Processing Record 17 of Set 3 | sao joao da barra
# Processing Record 18 of Set 3 | zastron
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | narasannapeta
# Processing Record 21 of Set 3 | gravdal
# Processing Record 22 of Set 3 | havre-saint-pierre
# Processing Record 23 of Set 3 | plettenberg bay
# Processing Record 24 of Set 3 | ratne
# Processing Record 25 of Set 3 | bathsheba
# Processing Record 26 of Set 3 | bubaque
# Processing Record 27 of Set 3 | port-cartier
# Processing Record 28 of Set 3 | red bank
# Processing Record 29 of Set 3 | ecublens
# Processing Record 30 of Set 3 | sao filipe
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | loubomo
# Processing Record 34 of Set 3 | villa maria
# Processing Record 35 of Set 3 | laguna
# Processing Record 36 of Set 3 | bagotville
# Processing Record 37 of Set 3 | augusto correa
# Processing Record 38 of Set 3 | monrovia
# Processing Record 39 of Set 3 | carovigno
# Processing Record 40 of Set 3 | sept-iles
# Processing Record 41 of Set 3 | baghdad
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | marawi
# Processing Record 44 of Set 3 | varadero
# Processing Record 45 of Set 3 | los llanos de aridane
# Processing Record 46 of Set 3 | noyabrsk
# Processing Record 47 of Set 3 | cockburn town
# Processing Record 48 of Set 3 | xai-xai
# Processing Record 49 of Set 3 | kano
# Processing Record 50 of Set 3 | comodoro rivadavia
# Processing Record 1 of Set 4 | ozinki
# Processing Record 2 of Set 4 | koroni
# Processing Record 3 of Set 4 | kazerun
# Processing Record 4 of Set 4 | lagoa
# Processing Record 5 of Set 4 | toftir
# City not found. Skipping...
# Processing Record 6 of Set 4 | sao miguel do araguaia
# Processing Record 7 of Set 4 | meulaboh
# Processing Record 8 of Set 4 | muros
# Processing Record 9 of Set 4 | nador
# Processing Record 10 of Set 4 | wattegama
# Processing Record 11 of Set 4 | dyurtyuli
# Processing Record 12 of Set 4 | malanje
# Processing Record 13 of Set 4 | akhtubinsk
# Processing Record 14 of Set 4 | kutum
# Processing Record 15 of Set 4 | berlevag
# Processing Record 16 of Set 4 | sabha
# Processing Record 17 of Set 4 | hofn
# Processing Record 18 of Set 4 | makinsk
# Processing Record 19 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 4 | pasaje
# Processing Record 21 of Set 4 | kutahya
# Processing Record 22 of Set 4 | viedma
# Processing Record 23 of Set 4 | sur
# Processing Record 24 of Set 4 | nuristan
# Processing Record 25 of Set 4 | artvin
# Processing Record 26 of Set 4 | benguela
# Processing Record 27 of Set 4 | tucuma
# Processing Record 28 of Set 4 | salcininkai
# Processing Record 29 of Set 4 | kargopol
# Processing Record 30 of Set 4 | thinadhoo
# Processing Record 31 of Set 4 | prado
# Processing Record 32 of Set 4 | tabas
# Processing Record 33 of Set 4 | harlingen
# Processing Record 34 of Set 4 | camacha
# Processing Record 35 of Set 4 | oistins
# Processing Record 36 of Set 4 | lamovita
# Processing Record 37 of Set 4 | saint-pierre
# Processing Record 38 of Set 4 | lalgudi
# Processing Record 39 of Set 4 | calahorra
# Processing Record 40 of Set 4 | namibe
# Processing Record 41 of Set 4 | vestmannaeyjar
# Processing Record 42 of Set 4 | shache
# Processing Record 43 of Set 4 | velyka bahachka
# Processing Record 44 of Set 4 | ostrovnoy
# Processing Record 45 of Set 4 | saint-augustin
# Processing Record 46 of Set 4 | tamandare
# Processing Record 47 of Set 4 | vila velha
# Processing Record 48 of Set 4 | taltal
# Processing Record 49 of Set 4 | carauari
# Processing Record 50 of Set 4 | christchurch
# Processing Record 1 of Set 5 | koslan
# Processing Record 2 of Set 5 | santiago
# Processing Record 3 of Set 5 | le vauclin
# Processing Record 4 of Set 5 | pachino
# Processing Record 5 of Set 5 | chato
# Processing Record 6 of Set 5 | skelleftea
# Processing Record 7 of Set 5 | la asuncion
# Processing Record 8 of Set 5 | mbandaka
# Processing Record 9 of Set 5 | ponta delgada
# Processing Record 10 of Set 5 | clyde river
# Processing Record 11 of Set 5 | sembe
# Processing Record 12 of Set 5 | calatayud
# Processing Record 13 of Set 5 | alberton
# Processing Record 14 of Set 5 | marzuq
# Processing Record 15 of Set 5 | carnarvon
# Processing Record 16 of Set 5 | klaksvik
# Processing Record 17 of Set 5 | san carlos de bariloche
# Processing Record 18 of Set 5 | kaduy
# Processing Record 19 of Set 5 | jackson
# Processing Record 20 of Set 5 | manta
# Processing Record 21 of Set 5 | vicuna
# Processing Record 22 of Set 5 | vuktyl
# Processing Record 23 of Set 5 | san cristobal
# Processing Record 24 of Set 5 | varazdin
# Processing Record 25 of Set 5 | demba
# Processing Record 26 of Set 5 | kidal
# Processing Record 27 of Set 5 | faya
# Processing Record 28 of Set 5 | felipe carrillo puerto
# Processing Record 29 of Set 5 | boa vista
# Processing Record 30 of Set 5 | biltine
# Processing Record 31 of Set 5 | oranjemund
# Processing Record 32 of Set 5 | arlit
# Processing Record 33 of Set 5 | porto nacional
# Processing Record 34 of Set 5 | bahir dar
# Processing Record 35 of Set 5 | quixada
# Processing Record 36 of Set 5 | gamba
# Processing Record 37 of Set 5 | kattivakkam
# Processing Record 38 of Set 5 | aswan
# Processing Record 39 of Set 5 | najran
# Processing Record 40 of Set 5 | sernur
# Processing Record 41 of Set 5 | belyy yar
# Processing Record 42 of Set 5 | hazorasp
# Processing Record 43 of Set 5 | ferme-neuve
# Processing Record 44 of Set 5 | olsztyn
# Processing Record 45 of Set 5 | kirchzarten
# Processing Record 46 of Set 5 | sinnamary
# Processing Record 47 of Set 5 | igarka
# Processing Record 48 of Set 5 | villa rica
# Processing Record 49 of Set 5 | los teques
# Processing Record 50 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 6 | fontem
# Processing Record 2 of Set 6 | vallenar
# Processing Record 3 of Set 6 | balkhash
# Processing Record 4 of Set 6 | lebanon
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | auray
# Processing Record 7 of Set 6 | dubenskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | pisco
# Processing Record 9 of Set 6 | razole
# Processing Record 10 of Set 6 | yar-sale
# Processing Record 11 of Set 6 | mumford
# Processing Record 12 of Set 6 | kurchum
# Processing Record 13 of Set 6 | abu dhabi
# Processing Record 14 of Set 6 | wilmington
# Processing Record 15 of Set 6 | aksarka
# Processing Record 16 of Set 6 | rennes
# Processing Record 17 of Set 6 | este
# Processing Record 18 of Set 6 | tahta
# Processing Record 19 of Set 6 | castro
# Processing Record 20 of Set 6 | olinda
# Processing Record 21 of Set 6 | peniche
# Processing Record 22 of Set 6 | palasa
# Processing Record 23 of Set 6 | kasangulu
# Processing Record 24 of Set 6 | kyshtovka
# Processing Record 25 of Set 6 | petauke
# Processing Record 26 of Set 6 | grand gaube
# Processing Record 27 of Set 6 | puerto el triunfo
# Processing Record 28 of Set 6 | marabba
# Processing Record 29 of Set 6 | andenes
# Processing Record 30 of Set 6 | karoi
# Processing Record 31 of Set 6 | madingou
# Processing Record 32 of Set 6 | malakal
# Processing Record 33 of Set 6 | nioro
# Processing Record 34 of Set 6 | souillac
# Processing Record 35 of Set 6 | esna
# Processing Record 36 of Set 6 | voyinka
# Processing Record 37 of Set 6 | paamiut
# Processing Record 38 of Set 6 | cap malheureux
# Processing Record 39 of Set 6 | springfield
# Processing Record 40 of Set 6 | ritchie
# Processing Record 41 of Set 6 | la rioja
# Processing Record 42 of Set 6 | yining
# Processing Record 43 of Set 6 | dovers
# Processing Record 44 of Set 6 | asfi
# Processing Record 45 of Set 6 | saldanha
# Processing Record 46 of Set 6 | agirish
# Processing Record 47 of Set 6 | inhambane
# Processing Record 48 of Set 6 | borama
# City not found. Skipping...
# Processing Record 49 of Set 6 | puerto ayacucho
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | vangaindrano
# Processing Record 2 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 7 | mangan
# Processing Record 5 of Set 7 | ambagarh chauki
# Processing Record 6 of Set 7 | alcains
# Processing Record 7 of Set 7 | effium
# Processing Record 8 of Set 7 | kabelvag
# Processing Record 9 of Set 7 | acajutla
# Processing Record 10 of Set 7 | kashi
# Processing Record 11 of Set 7 | nanortalik
# Processing Record 12 of Set 7 | kraliky
# Processing Record 13 of Set 7 | ginir
# Processing Record 14 of Set 7 | mombaca
# Processing Record 15 of Set 7 | torbay
# Processing Record 16 of Set 7 | taoudenni
# Processing Record 17 of Set 7 | udala
# Processing Record 18 of Set 7 | amapa
# Processing Record 19 of Set 7 | oak ridge
# Processing Record 20 of Set 7 | kvareli
# Processing Record 21 of Set 7 | salinopolis
# Processing Record 22 of Set 7 | villapinzon
# Processing Record 23 of Set 7 | hamilton
# Processing Record 24 of Set 7 | kismayo
# Processing Record 25 of Set 7 | gurbuki
# Processing Record 26 of Set 7 | garwolin
# Processing Record 27 of Set 7 | trelleborg
# Processing Record 28 of Set 7 | khandbari
# Processing Record 29 of Set 7 | kindu
# Processing Record 30 of Set 7 | busembatia
# Processing Record 31 of Set 7 | salym
# Processing Record 32 of Set 7 | santa marta
# Processing Record 33 of Set 7 | leo
# Processing Record 34 of Set 7 | savannah bight
# Processing Record 35 of Set 7 | agadez
# Processing Record 36 of Set 7 | ust-kan
# Processing Record 37 of Set 7 | rocha
# Processing Record 38 of Set 7 | butembo
# Processing Record 39 of Set 7 | talcahuano
# Processing Record 40 of Set 7 | albany
# Processing Record 41 of Set 7 | sorada
# Processing Record 42 of Set 7 | bilma
# Processing Record 43 of Set 7 | halifax
# Processing Record 44 of Set 7 | amos
# Processing Record 45 of Set 7 | freetown
# Processing Record 46 of Set 7 | santo domingo
# Processing Record 47 of Set 7 | kudahuvadhoo
# Processing Record 48 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 49 of Set 7 | itacare
# Processing Record 50 of Set 7 | moussoro
# Processing Record 1 of Set 8 | kargasok
# Processing Record 2 of Set 8 | santa cruz
# Processing Record 3 of Set 8 | nizhnevartovsk
# Processing Record 4 of Set 8 | aranos
# Processing Record 5 of Set 8 | valparaiso
# Processing Record 6 of Set 8 | salalah
# Processing Record 7 of Set 8 | kuryk
# Processing Record 8 of Set 8 | vardo
# Processing Record 9 of Set 8 | cherdyn
# Processing Record 10 of Set 8 | wana
# Processing Record 11 of Set 8 | escanaba
# Processing Record 12 of Set 8 | aksu
# Processing Record 13 of Set 8 | shahr-e kord
# Processing Record 14 of Set 8 | wausau
# Processing Record 15 of Set 8 | colares
# Processing Record 16 of Set 8 | teguise
# Processing Record 17 of Set 8 | odlabari
# Processing Record 18 of Set 8 | urucara
# Processing Record 19 of Set 8 | walvis bay
# Processing Record 20 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 8 | gat
# Processing Record 22 of Set 8 | ekibastuz
# Processing Record 23 of Set 8 | beysehir
# Processing Record 24 of Set 8 | rabo de peixe
# Processing Record 25 of Set 8 | ballina
# Processing Record 26 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 8 | khonsar
# City not found. Skipping...
# Processing Record 28 of Set 8 | ajdabiya
# Processing Record 29 of Set 8 | leh
# Processing Record 30 of Set 8 | tyukalinsk
# Processing Record 31 of Set 8 | chapais
# Processing Record 32 of Set 8 | saint anthony
# Processing Record 33 of Set 8 | tres coracoes
# Processing Record 34 of Set 8 | colesberg
# Processing Record 35 of Set 8 | matara
# Processing Record 36 of Set 8 | touros
# Processing Record 37 of Set 8 | ahtopol
# Processing Record 38 of Set 8 | beloha
# Processing Record 39 of Set 8 | susehri
# Processing Record 40 of Set 8 | rawson
# Processing Record 41 of Set 8 | merritt island
# Processing Record 42 of Set 8 | puerto del rosario
# Processing Record 43 of Set 8 | turtas
# Processing Record 44 of Set 8 | bastia
# Processing Record 45 of Set 8 | tohana
# Processing Record 46 of Set 8 | talara
# Processing Record 47 of Set 8 | gidole
# Processing Record 48 of Set 8 | sergeyevka
# Processing Record 49 of Set 8 | porto novo
# Processing Record 50 of Set 8 | burica
# City not found. Skipping...
# Processing Record 1 of Set 9 | henties bay
# Processing Record 2 of Set 9 | high rock
# Processing Record 3 of Set 9 | pemba
# Processing Record 4 of Set 9 | wisla
# Processing Record 5 of Set 9 | januaria
# Processing Record 6 of Set 9 | challans
# Processing Record 7 of Set 9 | havoysund
# Processing Record 8 of Set 9 | maniitsoq
# Processing Record 9 of Set 9 | oneida
# Processing Record 10 of Set 9 | shakawe
# Processing Record 11 of Set 9 | mohpa
# Processing Record 12 of Set 9 | porto santo
# Processing Record 13 of Set 9 | prieska
# Processing Record 14 of Set 9 | mogadishu
# Processing Record 15 of Set 9 | obigarm
# Processing Record 16 of Set 9 | ugoofaaru
# Processing Record 17 of Set 9 | leshukonskoye
# Processing Record 18 of Set 9 | camacupa
# Processing Record 19 of Set 9 | acari
# Processing Record 20 of Set 9 | duz
# City not found. Skipping...
# Processing Record 21 of Set 9 | bindki
# Processing Record 22 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 9 | voi
# Processing Record 24 of Set 9 | nueva loja
# Processing Record 25 of Set 9 | virginia beach
# Processing Record 26 of Set 9 | vila franca do campo
# Processing Record 27 of Set 9 | kavaratti
# Processing Record 28 of Set 9 | dubai
# Processing Record 29 of Set 9 | alferrarede
# Processing Record 30 of Set 9 | conceicao do mato dentro
# Processing Record 31 of Set 9 | buraydah
# Processing Record 32 of Set 9 | were ilu
# Processing Record 33 of Set 9 | jacareacanga
# Processing Record 34 of Set 9 | westport
# Processing Record 35 of Set 9 | tocopilla
# Processing Record 36 of Set 9 | kushmurun
# Processing Record 37 of Set 9 | tuntange
# Processing Record 38 of Set 9 | segezha
# Processing Record 39 of Set 9 | raudeberg
# Processing Record 40 of Set 9 | cabedelo
# Processing Record 41 of Set 9 | igarape-miri
# City not found. Skipping...
# Processing Record 42 of Set 9 | tutoia
# Processing Record 43 of Set 9 | nueve de julio
# Processing Record 44 of Set 9 | geraldton
# Processing Record 45 of Set 9 | sonqor
# Processing Record 46 of Set 9 | porbandar
# Processing Record 47 of Set 9 | wolmaranstad
# City not found. Skipping...
# Processing Record 48 of Set 9 | araguatins
# City not found. Skipping...
# Processing Record 49 of Set 9 | lisala
# Processing Record 50 of Set 9 | newnan
# Processing Record 1 of Set 10 | skibbereen
# Processing Record 2 of Set 10 | exu
# Processing Record 3 of Set 10 | chicama
# Processing Record 4 of Set 10 | harbour breton
# Processing Record 5 of Set 10 | jabinyanah
# Processing Record 6 of Set 10 | mahibadhoo
# Processing Record 7 of Set 10 | ambovombe
# Processing Record 8 of Set 10 | mangrol
# Processing Record 9 of Set 10 | tiznit
# Processing Record 10 of Set 10 | presidencia roque saenz pena
# Processing Record 11 of Set 10 | road town
# Processing Record 12 of Set 10 | tambura
# Processing Record 13 of Set 10 | plouzane
# Processing Record 14 of Set 10 | sisimiut
# Processing Record 15 of Set 10 | nalut
# Processing Record 16 of Set 10 | doka
# Processing Record 17 of Set 10 | alta floresta
# Processing Record 18 of Set 10 | mayumba
# Processing Record 19 of Set 10 | mehamn
# Processing Record 20 of Set 10 | margate
# Processing Record 21 of Set 10 | quevedo
# Processing Record 22 of Set 10 | aktash
# Processing Record 23 of Set 10 | karakol
# Processing Record 24 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 25 of Set 10 | issenye
# Processing Record 26 of Set 10 | bandarbeyla
# Processing Record 27 of Set 10 | brokopondo
# Processing Record 28 of Set 10 | barcelona
# Processing Record 29 of Set 10 | kovdor
# Processing Record 30 of Set 10 | umm lajj
# Processing Record 31 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 10 | bela vista
# Processing Record 35 of Set 10 | yelan
# Processing Record 36 of Set 10 | lebu
# Processing Record 37 of Set 10 | araguacu
# Processing Record 38 of Set 10 | svetlyy
# Processing Record 39 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 40 of Set 10 | humaita
# Processing Record 41 of Set 10 | opuwo
# Processing Record 42 of Set 10 | kaduqli
# Processing Record 43 of Set 10 | windsor
# Processing Record 44 of Set 10 | iturama
# Processing Record 45 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | mecca
# Processing Record 47 of Set 10 | resistencia
# Processing Record 48 of Set 10 | adrar
# Processing Record 49 of Set 10 | orangeburg
# Processing Record 50 of Set 10 | vagur
# Processing Record 1 of Set 11 | at-bashi
# Processing Record 2 of Set 11 | boende
# Processing Record 3 of Set 11 | north vernon
# Processing Record 4 of Set 11 | conceicao do araguaia
# Processing Record 5 of Set 11 | sayan
# Processing Record 6 of Set 11 | nadym
# Processing Record 7 of Set 11 | pavino
# Processing Record 8 of Set 11 | zhob
# Processing Record 9 of Set 11 | belmonte
# Processing Record 10 of Set 11 | acarau
# Processing Record 11 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 11 | recreio
# Processing Record 13 of Set 11 | bull savanna
# Processing Record 14 of Set 11 | carndonagh
# Processing Record 15 of Set 11 | itacarambi
# Processing Record 16 of Set 11 | mantua
# Processing Record 17 of Set 11 | lasa
# Processing Record 18 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 19 of Set 11 | takoradi
# Processing Record 20 of Set 11 | tokonou
# Processing Record 21 of Set 11 | kangaatsiaq
# Processing Record 22 of Set 11 | rouvroy
# Processing Record 23 of Set 11 | alekseyevka
# Processing Record 24 of Set 11 | saint-medard-en-jalles
# Processing Record 25 of Set 11 | visnes
# Processing Record 26 of Set 11 | the valley
# Processing Record 27 of Set 11 | nouakchott
# Processing Record 28 of Set 11 | woodstock
# Processing Record 29 of Set 11 | carballo
# Processing Record 30 of Set 11 | aroneanu
# Processing Record 31 of Set 11 | shelburne
# Processing Record 32 of Set 11 | druzhba
# Processing Record 33 of Set 11 | kallaste
# Processing Record 34 of Set 11 | shigony
# Processing Record 35 of Set 11 | waslala
# Processing Record 36 of Set 11 | grand-santi
# Processing Record 37 of Set 11 | mao
# Processing Record 38 of Set 11 | tera
# Processing Record 39 of Set 11 | vila do maio
# Processing Record 40 of Set 11 | pangoa
# Processing Record 41 of Set 11 | coquimbo
# Processing Record 42 of Set 11 | kirkcudbright
# Processing Record 43 of Set 11 | nizwa
# Processing Record 44 of Set 11 | brae
# Processing Record 45 of Set 11 | triolet
# Processing Record 46 of Set 11 | oriximina
# Processing Record 47 of Set 11 | aasiaat
# Processing Record 48 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 11 | barcelos
# Processing Record 50 of Set 11 | sinop
# Processing Record 1 of Set 12 | gurupa
# Processing Record 2 of Set 12 | crestview
# Processing Record 3 of Set 12 | esil
# Processing Record 4 of Set 12 | tias
# Processing Record 5 of Set 12 | mantes-la-ville
# Processing Record 6 of Set 12 | storforshei
# Processing Record 7 of Set 12 | tonj
# Processing Record 8 of Set 12 | qasigiannguit
# Processing Record 9 of Set 12 | trincomalee
# Processing Record 10 of Set 12 | la vega
# Processing Record 11 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 12 | kyabe
# Processing Record 13 of Set 12 | perevolotskiy
# Processing Record 14 of Set 12 | livramento
# Processing Record 15 of Set 12 | atar
# Processing Record 16 of Set 12 | petershagen
# Processing Record 17 of Set 12 | sturgeon bay
# Processing Record 18 of Set 12 | zadar
# Processing Record 19 of Set 12 | dwarka
# Processing Record 20 of Set 12 | nouadhibou
# Processing Record 21 of Set 12 | yarmouth
# Processing Record 22 of Set 12 | tres arroyos
# Processing Record 23 of Set 12 | monroe
# Processing Record 24 of Set 12 | chor
# Processing Record 25 of Set 12 | zavyalovo
# Processing Record 26 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 12 | abu zabad
# Processing Record 28 of Set 12 | beyneu
# Processing Record 29 of Set 12 | lokoja
# Processing Record 30 of Set 12 | nuuk
# Processing Record 31 of Set 12 | posse
# Processing Record 32 of Set 12 | makushino
# Processing Record 33 of Set 12 | inirida
# Processing Record 34 of Set 12 | stephenville
# Processing Record 35 of Set 12 | maurepas
# Processing Record 36 of Set 12 | sao joao de pirabas
# Processing Record 37 of Set 12 | madawaska
# Processing Record 38 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 12 | olafsvik
# Processing Record 40 of Set 12 | nsanje
# Processing Record 41 of Set 12 | tete
# Processing Record 42 of Set 12 | cozumel
# Processing Record 43 of Set 12 | vigrestad
# Processing Record 44 of Set 12 | san vicente
# Processing Record 45 of Set 12 | karlskoga
# Processing Record 46 of Set 12 | tunceli
# Processing Record 47 of Set 12 | knokke-heist
# Processing Record 48 of Set 12 | komatipoort
# Processing Record 49 of Set 12 | warah
# Processing Record 50 of Set 12 | nurobod
# Processing Record 1 of Set 13 | kardailovo
# Processing Record 2 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 13 | berwick
# Processing Record 4 of Set 13 | cananeia
# Processing Record 5 of Set 13 | manicore
# Processing Record 6 of Set 13 | sorsk
# Processing Record 7 of Set 13 | morondava
# Processing Record 8 of Set 13 | abdulino
# Processing Record 9 of Set 13 | ust-koksa
# Processing Record 10 of Set 13 | saint-denis
# Processing Record 11 of Set 13 | serik
# Processing Record 12 of Set 13 | louis trichardt
# Processing Record 13 of Set 13 | bafra
# Processing Record 14 of Set 13 | pokhara
# Processing Record 15 of Set 13 | necochea
# Processing Record 16 of Set 13 | mponela
# Processing Record 17 of Set 13 | itarema
# Processing Record 18 of Set 13 | dudinka
# Processing Record 19 of Set 13 | garoua boulai
# Processing Record 20 of Set 13 | chebsara
# Processing Record 21 of Set 13 | kouango
# Processing Record 22 of Set 13 | sfantu gheorghe
# Processing Record 23 of Set 13 | ibia
# Processing Record 24 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 25 of Set 13 | bud
# Processing Record 26 of Set 13 | temba
# Processing Record 27 of Set 13 | mgandu
# Processing Record 28 of Set 13 | labrea
# Processing Record 29 of Set 13 | tessalit
# Processing Record 30 of Set 13 | monsenhor gil
# Processing Record 31 of Set 13 | camana
# Processing Record 32 of Set 13 | elat
# Processing Record 33 of Set 13 | sorland
# Processing Record 34 of Set 13 | havelock
# Processing Record 35 of Set 13 | dawlatabad
# Processing Record 36 of Set 13 | mbanza-ngungu
# Processing Record 37 of Set 13 | jamkhed
# Processing Record 38 of Set 13 | monte santo de minas
# Processing Record 39 of Set 13 | santiago del estero
# Processing Record 40 of Set 13 | warrington
# Processing Record 41 of Set 13 | jalu
# Processing Record 42 of Set 13 | vetlanda
# Processing Record 43 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 13 | soyo
# Processing Record 45 of Set 13 | rudbar
# Processing Record 46 of Set 13 | vesyegonsk
# Processing Record 47 of Set 13 | bulz
# Processing Record 48 of Set 13 | kisangani
# Processing Record 49 of Set 13 | lentekhi
# Processing Record 50 of Set 13 | jumla
# Processing Record 1 of Set 14 | horasan
# Processing Record 2 of Set 14 | benghazi
# Processing Record 3 of Set 14 | savalou
# Processing Record 4 of Set 14 | eregli
# Processing Record 5 of Set 14 | karatau
# Processing Record 6 of Set 14 | kambove
# Processing Record 7 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 14 | keti bandar
# Processing Record 9 of Set 14 | bida
# Processing Record 10 of Set 14 | maragogi
# Processing Record 11 of Set 14 | killin
# Processing Record 12 of Set 14 | jaque
# Processing Record 13 of Set 14 | erzincan
# Processing Record 14 of Set 14 | rio grande
# Processing Record 15 of Set 14 | villa carlos paz
# Processing Record 16 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 14 | inta
# Processing Record 18 of Set 14 | burlatskoye
# Processing Record 19 of Set 14 | le port
# Processing Record 20 of Set 14 | fartura
# Processing Record 21 of Set 14 | maltahohe
# Processing Record 22 of Set 14 | pedasi
# Processing Record 23 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 24 of Set 14 | tutin
# Processing Record 25 of Set 14 | hautmont
# Processing Record 26 of Set 14 | uyo
# Processing Record 27 of Set 14 | kurchatov
# Processing Record 28 of Set 14 | nantucket
# Processing Record 29 of Set 14 | katsina
# Processing Record 30 of Set 14 | gornyak
# Processing Record 31 of Set 14 | piste
# Processing Record 32 of Set 14 | zhezkazgan
# Processing Record 33 of Set 14 | yecla
# Processing Record 34 of Set 14 | bonavista
# Processing Record 35 of Set 14 | kitgum
# Processing Record 36 of Set 14 | pitimbu
# Processing Record 37 of Set 14 | kharod
# Processing Record 38 of Set 14 | gobabis
# Processing Record 39 of Set 14 | nybro
# Processing Record 40 of Set 14 | talnakh
# Processing Record 41 of Set 14 | lere
# Processing Record 42 of Set 14 | bambari
# Processing Record 43 of Set 14 | crotone
# Processing Record 44 of Set 14 | doha
# Processing Record 45 of Set 14 | san jose
# Processing Record 46 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 14 | calamar
# Processing Record 48 of Set 14 | senneterre
# Processing Record 49 of Set 14 | kabalo
# Processing Record 50 of Set 14 | chhindwara
# Processing Record 1 of Set 15 | chingola
# Processing Record 2 of Set 15 | rawah
# Processing Record 3 of Set 15 | saint-georges
# Processing Record 4 of Set 15 | conchas
# Processing Record 5 of Set 15 | kastamonu
# Processing Record 6 of Set 15 | ordzhonikidze
# Processing Record 7 of Set 15 | mandera
# Processing Record 8 of Set 15 | villazon
# Processing Record 9 of Set 15 | coleraine
# Processing Record 10 of Set 15 | zarubino
# Processing Record 11 of Set 15 | turayf
# Processing Record 12 of Set 15 | sochi
# Processing Record 13 of Set 15 | bandundu
# Processing Record 14 of Set 15 | nokaneng
# Processing Record 15 of Set 15 | leninogorsk
# Processing Record 16 of Set 15 | derazhnya
# Processing Record 17 of Set 15 | calvinia
# Processing Record 18 of Set 15 | marystown
# Processing Record 19 of Set 15 | bay roberts
# Processing Record 20 of Set 15 | salta
# Processing Record 21 of Set 15 | zdvinsk
# Processing Record 22 of Set 15 | matay
# Processing Record 23 of Set 15 | huayucachi
# Processing Record 24 of Set 15 | port-gentil
# Processing Record 25 of Set 15 | miandrivazo
# Processing Record 26 of Set 15 | volga
# Processing Record 27 of Set 15 | basoko
# Processing Record 28 of Set 15 | loralai
# Processing Record 29 of Set 15 | decatur
# Processing Record 30 of Set 15 | muyezerskiy
# Processing Record 31 of Set 15 | barra patuca
# Processing Record 32 of Set 15 | gasa
# Processing Record 33 of Set 15 | tokat
# Processing Record 34 of Set 15 | balkanabat
# Processing Record 35 of Set 15 | carutapera
# Processing Record 36 of Set 15 | neuquen
# Processing Record 37 of Set 15 | praia da vitoria
# Processing Record 38 of Set 15 | taybad
# Processing Record 39 of Set 15 | podgornoye
# Processing Record 40 of Set 15 | hinganghat
# Processing Record 41 of Set 15 | tazovskiy
# Processing Record 42 of Set 15 | araouane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Grindavik      IS  63.8424 -22.4338     49.95        81          75
# 1         Tonantins      BR  -2.8731 -67.8022     92.03        44          89
# 2  Nauchnyy Gorodok      RU  53.4203  83.5210     43.66        52           0
# 3       East London      ZA -33.0153  27.9116     63.54        94          40
# 4    Kumylzhenskaya      RU  49.8809  42.5898     66.97        97         100
# 5            Cahors      FR  44.4167   1.3333     62.96        48         100
# 6         Coihaique      CL -45.5752 -72.0662     44.55        45          40
# 7        Bredasdorp      ZA -34.5322  20.0403     56.77        91          53
# 8             Ancud      CL -41.8697 -73.8203     47.23        51         100
# 9    Ribeira Grande      PT  38.5167 -28.7000     77.40        78          20
#
#    Wind Speed Current Description
# 0        5.75       broken clouds
# 1        3.31     overcast clouds
# 2        8.95           clear sky
# 3        9.22    scattered clouds
# 4        6.40       moderate rain
# 5        8.72     overcast clouds
# 6        8.05    scattered clouds
# 7       10.36       broken clouds
# 8        9.44     overcast clouds
# 9       13.80          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
